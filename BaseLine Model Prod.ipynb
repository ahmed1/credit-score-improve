# %%
import os
import pandas as pd
import numpy as np

from sklearn import model_selection

import sagemaker
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker import get_execution_role
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner

import clean_data


raw = pd.read_csv('05_pretrain_wID.csv')
raw.drop(columns = {'Unnamed: 0'}, inplace = True)

# %%
raw.head()
# Out:
#                                      ID  score type  high_credit  balance  \
# 0  44890d77-94da-49a5-8eef-0bdcf7f65979    373  EDU        18326        0
# 1  44890d77-94da-49a5-8eef-0bdcf7f65979    373  EDU        18326        0
# 2  44890d77-94da-49a5-8eef-0bdcf7f65979    373  EDU        18326        0
# 3  44890d77-94da-49a5-8eef-0bdcf7f65979    373  EDU        18326        0
# 4  44890d77-94da-49a5-8eef-0bdcf7f65979    373  EDU        18326        0
#
#    active status  overdue status_payment
# 0   False   PAID        0        ON TIME
# 1   False   PAID        0        ON TIME
# 2   False   PAID        0        ON TIME
# 3   False   PAID        0        ON TIME
# 4   False   PAID        0        ON TIME

# %%
# call Preprocess
prepro_in = clean_data.PreprocessBaseline(raw)
df, X = prepro_in()

# %%
train = df.iloc[:1900060]
val = df.iloc[1900060:]
train.drop(columns = {'ID'}, inplace = True)
val.drop(columns = {'ID'}, inplace = True)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
# model
data_dir = '../data-prod'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

train.to_csv(os.path.join(data_dir, 'train.csv'), header = None, index = None)
val.to_csv(os.path.join(data_dir, 'validation.csv'), header = None, index = None)



session = sagemaker.Session()

prefix = '02-model'
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), 
                                     key_prefix = prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), 
                                   key_prefix = prefix)

container = get_image_uri(session.boto_region_name, 'xgboost')
role = get_execution_role()

xgb = sagemaker.estimator.Estimator(container, role, train_instance_count=1,
                                   train_instance_type = 'ml.m4.10xlarge',
                                   output_path = 's3://{}/{}/output'.format(session.default_bucket(), prefix),
                                   sagemaker_session = session)


xgb.set_hyperparameters(max_depth=5, eta=0.2, gamma=4, min_child_weight=6,
                       subsample=0.6, objective='reg:linear', num_round=200)


xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb, 
                                               objective_metric_name = 'validation:rmse', 
                                               objective_type = 'Minimize', 
                                               max_jobs = 20, 
                                               max_parallel_jobs = 1, 
                                               hyperparameter_ranges = {
                                                    'max_depth': IntegerParameter(3, 12),
                                                    'eta'      : ContinuousParameter(0.05, 0.5),
                                                    'min_child_weight': IntegerParameter(2, 8),
                                                    'subsample': ContinuousParameter(0.5, 0.9),
                                                    'gamma': ContinuousParameter(0, 10),
                                               })

# wrapper
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type = 'csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')

xgb_hyperparameter_tuner.fit({'train' : s3_input_train, 'validation' : s3_input_validation})


xgb_hyperparameter_tuner.wait()
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').
# ..................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................!

# %%
xgb_hyperparameter_tuner.best_training_job()
# Out:
# 'xgboost-200702-2126-013-67dc7500'

# %%
xgb_attached = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())
# Out:
# 2020-07-02 22:30:23 Starting - Preparing the instances for training
# 2020-07-02 22:30:23 Downloading - Downloading input data
# 2020-07-02 22:30:23 Training - Training image download completed. Training in progress.
# 2020-07-02 22:30:23 Uploading - Uploading generated training model
# 2020-07-02 22:30:23 Completed - Training job completedArguments: train
# [2020-07-02:22:29:36:INFO] Running standalone xgboost training.
# [2020-07-02:22:29:36:INFO] Setting up HPO optimized metric to be : rmse
# [2020-07-02:22:29:36:INFO] File size need to be processed in the node: 209.9mb. Available memory size in the node: 152511.04mb
# [2020-07-02:22:29:36:INFO] Determined delimiter of CSV input is ','
# [22:29:36] S3DistributionType set as FullyReplicated
# [22:29:36] 1900060x14 matrix with 26600840 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-07-02:22:29:36:INFO] Determined delimiter of CSV input is ','
# [22:29:36] S3DistributionType set as FullyReplicated
# [22:29:36] 261298x14 matrix with 3658172 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [22:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [0]#011train-rmse:1.10251#011validation-rmse:1.12616
# [22:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [1]#011train-rmse:1.09116#011validation-rmse:1.11359
# [22:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [2]#011train-rmse:1.08081#011validation-rmse:1.10209
# [22:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [3]#011train-rmse:1.07143#011validation-rmse:1.09153
# [22:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [4]#011train-rmse:1.06291#011validation-rmse:1.08196
# [22:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [5]#011train-rmse:1.05516#011validation-rmse:1.07327
# [22:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [6]#011train-rmse:1.04815#011validation-rmse:1.06534
# [22:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [7]#011train-rmse:1.04177#011validation-rmse:1.05801
# [22:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [8]#011train-rmse:1.03598#011validation-rmse:1.05125
# [22:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [9]#011train-rmse:1.03073#011validation-rmse:1.04507
# [22:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [10]#011train-rmse:1.02598#011validation-rmse:1.03954
# [22:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11]#011train-rmse:1.02168#011validation-rmse:1.03442
# [22:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [12]#011train-rmse:1.01779#011validation-rmse:1.02975
# [22:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [13]#011train-rmse:1.01426#011validation-rmse:1.02548
# [22:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [14]#011train-rmse:1.01109#011validation-rmse:1.0216
# [22:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [15]#011train-rmse:1.0082#011validation-rmse:1.01804
# [22:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [16]#011train-rmse:1.0056#011validation-rmse:1.01479
# [22:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [17]#011train-rmse:1.00321#011validation-rmse:1.01181
# [22:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [18]#011train-rmse:1.00106#011validation-rmse:1.00912
# [22:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19]#011train-rmse:0.999144#011validation-rmse:1.00661
# [22:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [20]#011train-rmse:0.99738#011validation-rmse:1.00437
# [22:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [21]#011train-rmse:0.995793#011validation-rmse:1.00229
# [22:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [22]#011train-rmse:0.994361#011validation-rmse:1.00042
# [22:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [23]#011train-rmse:0.993076#011validation-rmse:0.998691
# [22:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [24]#011train-rmse:0.991913#011validation-rmse:0.997117
# [22:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [25]#011train-rmse:0.990846#011validation-rmse:0.995667
# [22:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [26]#011train-rmse:0.989873#011validation-rmse:0.99434
# [22:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [27]#011train-rmse:0.989004#011validation-rmse:0.993106
# [22:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [28]#011train-rmse:0.988216#011validation-rmse:0.99202
# [22:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [29]#011train-rmse:0.987497#011validation-rmse:0.990981
# [22:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [30]#011train-rmse:0.986859#011validation-rmse:0.990018
# [22:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [31]#011train-rmse:0.986234#011validation-rmse:0.989139
# [22:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [32]#011train-rmse:0.985694#011validation-rmse:0.988333
# [22:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
#
59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [120]#011train-rmse:0.978928#011validation-rmse:0.978234
# [22:29:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [121]#011train-rmse:0.978907#011validation-rmse:0.978251
# [22:29:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [122]#011train-rmse:0.978893#011validation-rmse:0.978274
# [22:30:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [123]#011train-rmse:0.978884#011validation-rmse:0.97827
# [22:30:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [124]#011train-rmse:0.978868#011validation-rmse:0.978257
# [22:30:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [125]#011train-rmse:0.978848#011validation-rmse:0.978264
# [22:30:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [126]#011train-rmse:0.978824#011validation-rmse:0.978267
# [22:30:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [127]#011train-rmse:0.978814#011validation-rmse:0.978267
# [22:30:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [128]#011train-rmse:0.978789#011validation-rmse:0.978262
# [22:30:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [129]#011train-rmse:0.978765#011validation-rmse:0.978271
# [22:30:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [130]#011train-rmse:0.978752#011validation-rmse:0.978254
# [22:30:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [131]#011train-rmse:0.978743#011validation-rmse:0.978252
# [22:30:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [132]#011train-rmse:0.978735#011validation-rmse:0.97826
# [22:30:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [133]#011train-rmse:0.978726#011validation-rmse:0.978266
# [22:30:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [134]#011train-rmse:0.978715#011validation-rmse:0.978274
# [22:30:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [135]#011train-rmse:0.978695#011validation-rmse:0.978262
# [22:30:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [136]#011train-rmse:0.978665#011validation-rmse:0.97825
# [22:30:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [137]#011train-rmse:0.97864#011validation-rmse:0.97826
# [22:30:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [138]#011train-rmse:0.978627#011validation-rmse:0.978273
# [22:30:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [139]#011train-rmse:0.978606#011validation-rmse:0.978264
# [22:30:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [140]#011train-rmse:0.978586#011validation-rmse:0.978288
# [22:30:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [141]#011train-rmse:0.978562#011validation-rmse:0.978275
# [22:30:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [142]#011train-rmse:0.978547#011validation-rmse:0.978269
# [22:30:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [143]#011train-rmse:0.978535#011validation-rmse:0.978274
# [22:30:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [144]#011train-rmse:0.978518#011validation-rmse:0.978274
# [22:30:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [145]#011train-rmse:0.978511#011validation-rmse:0.97827
# [22:30:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [146]#011train-rmse:0.978481#011validation-rmse:0.978269
# [22:30:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [147]#011train-rmse:0.978456#011validation-rmse:0.978266
# [22:30:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [148]#011train-rmse:0.978437#011validation-rmse:0.978275
# [22:30:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [149]#011train-rmse:0.978424#011validation-rmse:0.978279
# [22:30:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [150]#011train-rmse:0.978404#011validation-rmse:0.978273
# [22:30:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [151]#011train-rmse:0.978381#011validation-rmse:0.978271
# [22:30:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [152]#011train-rmse:0.978368#011validation-rmse:0.978269
# [22:30:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [153]#011train-rmse:0.978356#011validation-rmse:0.97827
# [22:30:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [154]#011train-rmse:0.978332#011validation-rmse:0.978255
# [22:30:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [155]#011train-rmse:0.978321#011validation-rmse:0.978245
# [22:30:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [156]#011train-rmse:0.978306#011validation-rmse:0.978256
# [22:30:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [157]#011train-rmse:0.97828#011validation-rmse:0.97826
# [22:30:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [158]#011train-rmse:0.978274#011validation-rmse:0.978271
# [22:30:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [159]#011train-rmse:0.978259#011validation-rmse:0.978269
# [22:30:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [160]#011train-rmse:0.978237#011validation-rmse:0.978262
# [22:30:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [161]#011train-rmse:0.978214#011validation-rmse:0.978236
# [22:30:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [162]#011train-rmse:0.978205#011validation-rmse:0.978241
# [22:30:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [163]#011train-rmse:0.978183#011validation-rmse:0.978253
# [22:30:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [164]#011train-rmse:0.978168#011validation-rmse:0.978256
# [22:30:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [165]#011train-rmse:0.978141#011validation-rmse:0.978267
# [22:30:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [166]#011train-rmse:0.978118#011validation-rmse:0.978272
# [22:30:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [167]#011train-rmse:0.978098#011validation-rmse:0.978271
# [22:30:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [168]#011train-rmse:0.978086#011validation-rmse:0.978264
# [22:30:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [169]#011train-rmse:0.978067#011validation-rmse:0.978282
# [22:30:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [170]#011train-rmse:0.978048#011validation-rmse:0.978285
# [22:30:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [171]#011train-rmse:0.97803#011validation-rmse:0.978286
# [22:30:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [172]#011train-rmse:0.978004#011validation-rmse:0.978292
# [22:30:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [173]#011train-rmse:0.977987#011validation-rmse:0.978297
# [22:30:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [174]#011train-rmse:0.977974#011validation-rmse:0.978292
# [22:30:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [175]#011train-rmse:0.977965#011validation-rmse:0.978292
# [22:30:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [176]#011train-rmse:0.977941#011validation-rmse:0.978279
# [22:30:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [177]#011train-rmse:0.977927#011validation-rmse:0.978283
# [22:30:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [178]#011train-rmse:0.977916#011validation-rmse:0.978277
# [22:30:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [179]#011train-rmse:0.977894#011validation-rmse:0.978301
# [22:30:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [180]#011train-rmse:0.97788#011validation-rmse:0.978317
# [22:30:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [181]#011train-rmse:0.977869#011validation-rmse:0.97834
# [22:30:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [182]#011train-rmse:0.977845#011validation-rmse:0.97835
# [22:30:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [183]#011train-rmse:0.977831#011validation-rmse:0.97835
# [22:30:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [184]#011train-rmse:0.977824#011validation-rmse:0.97836
# [22:30:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [185]#011train-rmse:0.97781#011validation-rmse:0.978347
# [22:30:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [186]#011train-rmse:0.977794#011validation-rmse:0.978335
# [22:30:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [187]#011train-rmse:0.977783#011validation-rmse:0.978344
# [22:30:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [188]#011train-rmse:0.97776#011validation-rmse:0.978351
# [22:30:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [189]#011train-rmse:0.977753#011validation-rmse:0.978346
# [22:30:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [190]#011train-rmse:0.977743#011validation-rmse:0.97835
# [22:30:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [191]#011train-rmse:0.977723#011validation-rmse:0.978373
# [22:30:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [192]#011train-rmse:0.977706#011validation-rmse:0.978366
# [22:30:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [193]#011train-rmse:0.977686#011validation-rmse:0.978378
# [22:30:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [194]#011train-rmse:0.977667#011validation-rmse:0.978375
# [22:30:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [195]#011train-rmse:0.977654#011validation-rmse:0.97838
# [22:30:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [196]#011train-rmse:0.977635#011validation-rmse:0.978386
# [22:30:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [197]#011train-rmse:0.97762#011validation-rmse:0.978389
# [22:30:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [198]#011train-rmse:0.977612#011validation-rmse:0.978384
# [22:30:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [199]#011train-rmse:0.977589#011validation-rmse:0.97839
# Training seconds: 89
# Billable seconds: 89

# %%
# get model back
session = sagemaker.Session()
role = get_execution_role()
container = get_image_uri(session.boto_region_name, 'xgboost')
xgb_attached = sagemaker.model.Model(model_data = 's3://sagemaker-us-east-1-922059106485/00-data/output/xgboost-200630-0734-018-5c272122/output/model.tar.gz',
                                    image= container,
                                    role = role)
# deploy
xgb_predictor = xgb_attached.deploy(initial_instance_count=1, instance_type = 'ml.t2.medium')
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').
# ---------------------!

# %%
xgb_predictor.endpoint
